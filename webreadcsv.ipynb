# %%
import pandas as pd
import gcsfs
from google.cloud import storage

# %%
client = storage.Client()

bucket_name = "bevdbbucket"
blobname = "Bevolkerungsdaten.csv"

bucket = client.get_bucket(bucket_name)
blob = bucket.get_blob(blobname)

df = pd.read_csv('gs://'+bucket_name+'/'+blobname, encoding='utf-8')
df
# Out:
# _request non-retriable exception: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object., 401
# Traceback (most recent call last):
#   File "c:\users\buchholz\appdata\local\programs\python\python39\lib\site-packages\gcsfs\retry.py", line 115, in retry_request
#     return await func(*args, **kwargs)
#   File "c:\users\buchholz\appdata\local\programs\python\python39\lib\site-packages\gcsfs\core.py", line 378, in _request
#     validate_response(status, contents, path, args)
#   File "c:\users\buchholz\appdata\local\programs\python\python39\lib\site-packages\gcsfs\retry.py", line 102, in validate_response
#     raise HttpError(error)
# gcsfs.retry.HttpError: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object., 401
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ...

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
file = "https://storage.googleapis.com/bevdbbucket/Bevolkerungsdaten.csv"
df = pd.read_csv(file, sep=";")
df
# Out:
#            index          Bundesland  Code_BL      Landkreis  Code_LK  \
# 0              0  Schleswig-Holstein        1      Flensburg     1001
# 1              1  Schleswig-Holstein        1      Flensburg     1001
# 2              2  Schleswig-Holstein        1      Flensburg     1001
# 3              3  Schleswig-Holstein        1      Flensburg     1001
# 4              4  Schleswig-Holstein        1      Flensburg     1001
# ...          ...                 ...      ...            ...      ...
# 5927098  1975696           Thüringen       16  Weimarer Land    16071
# 5927099  1975697           Thüringen       16  Weimarer Land    16071
# 5927100  1975698           Thüringen       16  Weimarer Land    16071
# 5927101  1975699           Thüringen       16  Weimarer Land    16071
# 5927102  1975700           Thüringen       16  Weimarer Land    16071
#
#            Gemeinde  Code_GM   Code                Art Prog/IST  Jahr  \
# ...

# %%
python gsutil iam ch allUsers:objectViewer gs://my-awesome-bucket

# %%
gcloud iam service-accounts keys create C:\Users\buchholz\AppData\Roaming\gcloud\legacy_credentials\buchholz@rosenbaum-nagy.de\keys.json --iam-account=p767514029773-zpmby2@gcp-sa-cloud-sql.iam.gserviceaccount.com

# %%
gcloud iam service-accounts keys create key.json --iam-account=buchholz@rosenbaum-nagy.de@rosenbaumnagy.iam.gserviceaccount.com
